# %% [markdown]
# ## Librerias a usar

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from IPython.display import display

# %% [markdown]
# ## Canciones rock

# %%
url = "https://www.last.fm/tag/rock/tracks?page=8"
h = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36 Edg/130.0.0.0"}
res = requests.get(url, headers=h)
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.text, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js playbar-masthead-release-shim youtube-provider-not-ready" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"0ed0ce50b0","applicationID":"5588594","transactionName":"Y1BRbUUFWkMEWxYMV1oadUxZB0BZClZNCV5ZG0RcVUpDRxIWAxVIRxtHWFBKQlkATxFfbEZUUFJEN0FSFVkFABZTUEc=","queueTime":0,"applicationTime":413,"agent":""};
# (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"UwYPV15QGwYFXFlXDgU=",licenseKey:"0ed0ce50b0",applicationID:"5588594"};;/*! For license information please see nr-loader-full-1.274.0.min.js.LICENSE.txt */
# (()=>{var e,t,r={8122:(e,t,r)=>{"use strict";r.d(t,{a:()=>i});var n=r(944);function i(e,t){try{if(!e||"object"!=typeof e)return(0,n.R)(3);if(!t||"object"!=typeof t)return(0,n.R)(4);const r=Object.create(Object.getPrototypeOf(t),Object.getOwnPropertyDescriptors(t)),o=0===Object.keys(r).length?e:r;for(let a in o)if(void 0!==e[a])try{if(null===e[a]){r[a]=null;continue}Array.isArray(e[a])&&Array.isArray(t[a])?r[a]=Array.from(new Set([...e[a],...t[a]])):"object"==typeof e[a]&&"object"==typeof t[a]?r[a]=i(e[a],t[a]):r[a]=e[a]}catch(e){(0,n.R)(1,e)}return r}catch(e){(0,n.R)(2,e)}}},2555:(e,t,r)=>{"use strict";r.d(t,{Vp:()=>c,fn:()=>s,x1:()=>d});var n=r(384),i=r(8122);const o={beacon:n.NT.beacon,errorBeacon:n.NT.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){try{const t=c(e);return!!t.licenseKey&&!!t.errorBeacon&&!!t.applicationID}catch(e){return!1}}function c(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function d(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.a)(t,o);const r=(0,n.nY)(e);r&&(r.info=a[e])}},9417:(e,t,r)=>{"use strict";r.d(t,{D0:()=>h,gD:()=>p,xN:()=>g});var n=r(993);const i=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var o=r(2614),a=r(944),s=r(384),c=r(8122);const d="[data-nr-mask]",u=()=>{const e={mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},feature_flags:[],generic_events:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},harvest:{tooManyRequestsDelay:60},jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},logging:{enabled:!0,harvestTimeSeconds:10,autoStart:!0,level:n.p_.INFO},metrics:{enabled:!0,autoStart:!0},obfuscate:void 0,page_action:{enabled:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},performance:{capture_marks:!1,capture_measures:!1},privacy:{cookies_enabled:!0},proxy:{assets:void 0,beacon:void 0},session:{expiresMs:o.wk,inactiveMs:o.BB},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,preload:!1,sampling_rate:10,error_sampling_rate:100,collect_fonts:!1,inline_images:!1,fix_stylesheets:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){i(t)?e.mask_selector="".concat(t,",").concat(d):""===t||null===t?e.mask_selector=d:(0,a.R)(5,t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){i(t)?e.block_selector+=",".concat(t):""!==t&&(0,a.R)(6,t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,a.R)(7,t)}},session_trace:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},soft_navigations:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},spa:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},ssl:void 0,user_actions:{enabled:!0}}},l={},f="All configuration objects require an agent identifier!";function h(e){if(!e)throw new Error(f);if(!l[e])throw new Error("Configuration for ".concat(e," was never set"));return l[e]}function g(e,t){if(!e)throw new Error(f);l[e]=(0,c.a)(t,u());const r=(0,s.nY)(e);r&&(r.ini ...
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title aria-live="assertive">Top rock tracks | Last.fm</title>
# <link data-replaceable-head-tag="" href="https://www.last.fm/tag/rock/tracks" rel="canonical"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/tag/rock/tracks" hreflang="en" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/de/tag/rock/tracks" hreflang="de" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/es/tag/rock/tracks" hreflang="es" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/fr/tag/rock/tracks" hreflang="fr" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/it/tag/rock/tracks" hreflang="it" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/ja/tag/rock/tracks" hreflang="ja" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/pl/tag/rock/tracks" hreflang="pl" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/pt/tag/rock/tracks" hreflang="pt" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/ru/tag/rock/tracks" hreflang="ru" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/sv/tag/rock/tracks" hreflang="sv" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/tr/tag/rock/tracks" hreflang="tr" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/zh/tag/rock/tracks" hreflang="zh" rel="alternate"/>
# <link data-replaceable-head-tag="" href="https://www.last.fm/tag/rock/tracks" hreflang="x-default" rel="alternate"/>
# <meta content="Browse the top rock tracks to find new music and discover artists. Listen online to rock music for free at Last.fm." data-replaceable-head-tag="" name="description"/>
# <meta content="Top rock tracks | Last.fm" data-replaceable-head-tag="" property="og:title"/>
# <meta content="Browse the top rock tracks to find new music and discover artists. Listen online to rock music for free at Last.fm." data-replaceable-head-tag="" property="og:description"/>
# <meta content="website" data-replaceable-head-tag="" property="og:type"/>
# <meta content="Last.fm" data-replaceable-head-tag="" property="og:site_name"/>
# <meta content="https://www.last.fm/tag/rock/tracks?page=8" data-replaceable-head-tag="" property="og:url">
# <meta content="https://www.last.fm/static/images/lastfm_logo_facebook.15d8133be114.png" data-replaceable-head-tag="" property="og:image"/>
# <meta content="1200" data-replaceable-head-tag="" property="og:image:width"/>
# <meta content="630" data-replaceable-head-tag="" property="og:image:height"/>
# <meta content="Top rock tracks | Last.fm" data-replaceable-head-tag="" name="twitter:title"/>
# <meta content="Browse the top rock tracks to find new music and discover artists. Listen online to rock music for free at Last.fm." data-replaceable-head-tag="" name="twitter:description"/>
# <meta content="https://www.last.fm/static/images/lastfm_avatar_twitter.52a5d69a85ac.png" data-replaceable-head-tag="" name="twitter:image"/>
# <meta content="summary" data-replaceable-head-tag="" name="twitter:card"/>
# <meta content="@lastfm" data-replaceable-head-tag="" name="twitter:site"/>
# <link href="https://www.last.fm/static/images/lastfm_avatar_applemusic.b06eb8ad89be.png" rel="apple-music-app-icon"/>
# <link href="https://www.last.fm/static/images/lastfm_avatar_applemusic.b06eb8ad89be.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://www.last.fm/static/images/lastfm_avatar_applemusic.b06eb8ad89be.png" rel="apple-touch-icon"/>
# <script type="text/javascript">
#         !(function (o, n) {
#             function $() {
#                 ($.q = $.q || []).push(arguments)
#             }
#
#             $.v = 1, o[n] = o[n] || $
#         })(window, String.fromCharCode(97, 100, 109, 105, 114, 97, 108));
#         !(function (t, c, i) {
#             i = t.createElement(c), t = t.getElementsByTagName(c)[0], i.async = 1, i.src = "https://strangeclocks.com/v2fjjH2X7fDDVyjq3kQFUt12y5wXOkb_ai99HR2WWrKQDN2VxaMxDPn0U", t.parentNode.insertBefore(i, t)
#         })(document, "script");
#         ;!(function (o, t, n, c) {
#             function e(n) {
#                 (function () {
#                     try {
#                         return (localStorage.getItem("v4ac1eiZr0") || "").split(",")[4] > 0
#                     } catch (o) {
#                     }
#                     return !1
#                 })() && (n = o[t].pubads()) && n.setTargeting("ae", "t")
#             }
#
#             (c = o[t] = o[t] || {}).cmd = c.cmd || [], typeof c.pubads === n ? e() : typeof c.cmd.unshift === n ? c.cmd.unshift(e) : c.cmd.push(e)
#         })(window, "googletag", "function");
#     </script>
# <script>(function(e) { e.className = e.className.replace(/\bno-js\b/,'js'); })(document.documentElement)</script>
# <link href="/static/images/favicon.702b239b6194.ico" rel="icon"/>
# <link charset="utf-8" data-stylesheet-name="defaults" href="/static/styles/build/anhv1-defaults-983daa777f.983daa777f56.css" rel="stylesheet"/>
# <link charset="utf-8" data-stylesheet-name="app" href="/static/styles/build/app-reduced-0f3172417d.d29f2cbf477f.css" rel="stylesheet"/>
# <link charset="utf-8" data-stylesheet-name="page-specific" href="/static/styles/build/tag-2f492db978.e65c588eeba0.css" rel="stylesheet"/>
# <link href="//cdn.cookielaw.org" rel="dns-prefetch">
# <link href="//cdn.privacy.paramount.com" rel="dns-prefetch">
# <script data-domain-script="d9f750da-0271-4142-9b0e-43d9a3b334d1" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js"></script>
# <script async="" id="bb-cbsoptanon" src="//cdn.privacy.paramount.com/dist/optanon-v1.1.0.js" type="text/javascript"></script>
# <script>
#             (function(a){
#               var w=window,b='cbsoptanon',q='cmd',r='config';
#               w[b] = w[b] ? w[b] : {};
#               w[b][q] = w[b][q] ? w[b][q] : [];
#               w[b][r] = w[b][r] ? w[b][r] : [];
#
#               a.forEach(function(z){
#                 w[b][z] = w[b][z] || function(){
#                   var c=arguments;
#                   w[b][q].push(function(){
#                     w[b][z].apply(w[b],c);
#                   })
#                 }
#               });
#             })(["onScriptsReady","onAdsReady"]);
#         </script>
# <script async="" data-main="/static/js-build/init.ff6902bb2ad6" src="/static/js-build/lib/require/require.9bf27e36bc89.js"></script>
# <!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
# <!--[if lt IE 9]>
#           <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#           <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script>
#         <![endif]-->
# </link></link></meta></head>
# <body class="two-column-layout anhv1 namespace--tag_tracks" data-anonymous="true" data-cbsi-player-config="/static/config/video-player.015786d691c2.xml" data-country-code="MX" data-facebook-placement-id="195612451022080_220502155199776" data-google-maps-api-key="AIzaSyBX6-IE3lz4PpJUSBVIo_dPb0BAyMgi-VE" data-onetrust-prod="" data-partial-refresh-supported="true" data-player-supported="true" data-require="ads/page-ads,ads/searchlinks,player/playlink-handler,dev/grid-overlay,dev/toggle-version,dev/debug-log,dev/debug-image-analysis,dev/js-log,dev/ads-toggle,components/link-block,components/ajax-form,core/media-size-events-v2" data-sensitive-path-regex="^/(../)?(googlec3ea1b252774e1ab\.html|account_deleted|inbox|join|login|lostpassword(/confirm)?|staff|subscribe|support(?!/images|/shouts|/shout)|settings/(account|website|subscription|password|lostpassword)|user/.+?/support)(/.*)?/?$" data-test-flag="disabled">
# <div data-require="tracking/tealium-utag-set" data-tealium-data='{"siteSection": "tag", "pageType": "tag_tracks", "pageName": "tag/tracks", "nativeEventTracking": true, "userState": "not authenticated", "userType": "anon"}' data-tealium-environment="prod" id="initial-tealium-data"></div>
# <div data-loading-indicator-copy="Loading…" data-require="components/loading-indicator"></div>
# <div data-require="components/open-modal,components/submit-to-modal,components/show-alert" data-show-alert-ok-copy="Okay"></div>
# <div class="intromercial lastfm-ad-mobile" data-ad="intromercial" data-ads-placement='{"id": "intromercial", "is_mobile_and_desktop": true, "out_of_page": true, "is_mobile": true}' id="intromercial" style="display: block;">
# </div>
# <div class="top-bar top-bar--v2">
# <div class="page-loading-logo page-loading-logo--placeholder" data-animation-path="/static/animations/logo_animate.a6f829b13446.json" data-require="components/page-loading-animation">
# <div class="page-loading-logo-container"></div>
# </div>
# </div>
# <div aria-live="polite" class="main-content" id="content" role="main">
# <div class="hidden" data-tealium-data='{"siteSection": "tag", "pageType": "tag_tracks", "pageName": "tag/tracks", "nativeEventTracking": true, "userState": "not authenticated", "userType": "anon"}' hidden="" id="tlmdata">
# </div>
# <div>
# <div data-require="components/disclose-base,components/disclose-autoclose-v2,components/disclose-dropdown-v2,components/disclose-dropdown-location-picker-v2,components/disclose-collapsing-nav-v2,components/disclose-artwork,components/disclose-remove,components/disclose-search,components/disclose-hover-v3,components/disclose-select,components/disclose-lazy-buylinks,components/focus-controls,components/prevent-resubmit-v2,components/edit-scrobble,components/edit-album,components/toggle-buttons,components/click-proxy,components/bookmark-notification,components/follow-notification,components/tourguide"></div>
# <nav class="masthead">
# <div class="masthead-inner-wrap masthead-inner-wrap--no-logo">
# <div class="masthead-logo">
# <a href="/">Last.fm</a>
# </div>
# <div class="masthead-nav-wrap">
# <a aria-controls="masthead-search" class="masthead-search-toggle" data-disclose-search="" href="/search">
#         Search
#     </a>
# <form action="/search" class="masthead-search-form disclose-hide disclose-hide--js-only" id="masthead-search" method="get">
# <div class="masthead-search-inner-wrap">
# <label class="sr-only" for="masthead-search-field">Search</label>
# <input class="masthead-search-field" id="masthead-search-field" name="q" placeholder="Search for music…" type="text"/>
# <button class="masthead-search-submit" type="submit">Search</button>
# </div>
# </form>
# <div class="visible-xs">
# <button aria-controls="masthead-nav" class="masthead-hamburger-toggle" data-disclose-autoclose="">
#                             Toggle navigation
#                         </button>
# <ul aria-label="Primary navigation" class="masthead-nav disclose-hide disclose-hide--js-only" id="masthead-nav">
# <li class="masthead-nav-item masthead-nav-pro">
# <a class="masthead-nav-control masthead-pro-text" data-analytics-action="UserMenuClick" data-analytics-label="subscribe" href="/pro">Upgrade to Pro</a>
# </li>
# <li class="masthead-nav-item">
# <a class="masthead-nav-control" data-analytics-action="NavigationLink" data-analytics-label="live" href="/dashboard">Live</a>
# </li>
# <li class="masthead-nav-item">
# <a class="masthead-nav-control" data-analytics-action="NavigationLink" data-analytics-label="music" href="/music">Music</a>
# </li>
# <li class="masthead-nav-item">
# <a class="masthead-nav-control" data-analytics-action="NavigationLink" data-analytics-label="charts" href="/charts">Charts</a>
# </li>
# <li class="masthead-nav-item">
# <a class="masthead-nav-control" data-analytics-action="NavigationLink" data-analytics-label="events" href="/events">Events</a>
# </li>
# <li class="masthead-nav-item">
# <a class="masthead-nav-control" data-analytics-action="UserMenuClick" data-analytics-label="subscribe" href="/pro">Subscribe</a>
# </li>
# <li class="masthead-nav-item">
# <a class="masthead-nav-control" href="/login">Log In</a>
# </li>
# <li class="masthead-nav-item masthead-nav-join">
# <a class="btn-secondary join-cta-button" data-analytics-action="SignUpClick" href="/join">Sign Up</a>
# </li>
# </ul>
# </div>
# <div class="navlist navlist--more masthead-nav hidden-xs" data-more-string="More…" data-require="components/primary-nav">
# <ul aria-label="Primary navigation" class="js-navlist-items navlist-items">
# <li class="masthead-nav-item masthead-nav-pro">
# <a class="masthead-nav-control masthead-pro-text" data-analytics-action="UserMenuClick" data-analytics-label="subscribe" href="/pro">Upgrade to Pro</a>
# </li>
# <li class="masthead-nav-item">
# <a class="masthead-nav-control" data-analytics-action="NavigationLink" data-analytics-label="live" href="/dashboard">Live</a>
# </li>
# <li class="masthead-nav-item">
# <a class="masthead-nav-control" data-analytics-action="NavigationLink" data-analytics-label="music" href="/music">Music</a>
# </li>
# <li class="masthead-nav-item">
# <a class="masthead-nav-control" data-analytics-action="NavigationLink" data-analytics-label="charts" href="/charts">Charts</a>
# </li>
# <li class="masthead-nav-item">
# <a class="masthead-nav-control" data-analytics-action="NavigationLink" data-analytics-label="events" href="/events">Events</a>
# </li>
# </ul>
# </div>
# <ul class="site-auth site-auth--anon hidden-xs">
# <li class="site-auth-item">
# <a class="site-auth-control" href="/login">
#             Log In
#         </a>
# </li>
# <li class="site-auth-item">
# <a class="site-auth-control btn-secondary join-cta-button" data-analytics-action="SignUpClick" href="/join">
#                 Sign Up
#             </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="" data-lazy-load-content="/nagbar/language-prompt" data-require="components/language-prompt">
# </div>
# <div data-require="core/redirect-bar" id="redirect-bar">
# <script id="redirect-bar-data" type="application/json">
#             {
#                 "content": {
#                     "redirect": "Redirected from {link}."
#                 },
#
#                     "overlayColor": null
#
#             }
#         </script>
# <redirect-bar></redirect-bar>
# </div>
# <header class="header header--sub-page header--tag">
# <div class="header-background header-background--has-image" style="background-image: url(https://lastfm.freetls.fastly.net/i/u/ar0/b2482f072c1745578d605602e7170619.jpg);"></div>
# <div class="recommended-next-page-container recommended-next-page-container--desktop-expanded recommended-next-page-container--mobile-hidden" data-require="components/recommended-next-page">
# <div class="js-link-block recommended-next-page recommended-next-page--tag">
# <img alt="" class="recommended-next-page-image" loading="lazy" src="https://lastfm.freetls.fastly.net/i/u/avatar70s/dc3c775e076d40cac0124c80b258365c.jpg"/>
# <div class="recommended-next-page-details">
# <h4 class="recommended-next-page-title">
#                 Recommended next
#             </h4>
# <a class="link-block-target recommended-next-page-name-unified" href="/tag/hard+rock">hard rock</a>
# <a class="link-block-target recommended-next-page-name" href="/tag/hard+rock">hard rock</a>
# </div>
# <span class="recommended-next-button"></span>
# <a aria-hidden="true" class="js-link-block-cover-link recommended-next-page-cover-link" data-analytics-action="RecommendedNextClick" href="/tag/hard+rock" tabindex="-1"></a>
# </div>
# </div>
# <div class="container">
# <div class="header-inner-wrap">
# <div class="header-info">
# <div class="header-info-primary header-info-primary--with-columns">
# <section class="share-mobile">
# <button aria-controls="share-bfa6f8c0-2678-4435-8a6a-a382635f44a9" aria-expanded="false" class="disclose-trigger share-button" data-analytics-action="ShareShowOptions" data-disclose-dropdown="" data-dropdown-layout-at="center bottom+5">
#             Share…
#         </button>
# <div class="disclose-hide disclose-hide--js-only share-block" id="share-bfa6f8c0-2678-4435-8a6a-a382635f44a9">
# <h2 class="share-heading">
#
#             Share this tag:
#
#     </h2>
# <ul class="share-options">
# <li class="share-option">
# <a data-analytics-social="2" href="https://www.facebook.com/sharer/sharer.php?ref=facebooklink&amp;u=https://www.last.fm/tag/rock/tracks?page=8" target="_blank">
# <img alt="Facebook" src="/static/images/icons/facebook.e0cc15e8e1d2.svg"/></a>
#
# </li>
# <li class="share-option">
# <a data-analytics-social="8" href="https://twitter.com/intent/tweet?url=https://www.last.fm/tag/rock/tracks?page=8&amp;via=lastfm&amp;lang=en&amp;text=Check+out+rock" target="_blank">
# <img alt="Twitter" src="/static/images/icons/twitter.841d4ebdbe86.svg"/></a>
#
# </li>
# </ul>
# </div>
# </section>
# <div class="header-info-primary-col1">
# <div class="header-title-column-ellipsis-wrap">
# <h1 class="header-title"><a href="/tag/rock">Rock music</a></h1>
# </div>
# <nav aria-label="Secondary navigation" class="navlist secondary-nav navlist--more" data-more-string="More…" data-require="components/collapsing-nav-v2">
# <ul class="navlist-items js-navlist-items">
# <li class="navlist-item secondary-nav-item secondary-nav-item--overview"><a class="secondary-nav-item-link" href="/tag/rock">
#                             Overview
#
#                         </a></li><li class="navlist-item secondary-nav-item secondary-nav-item--artists"><a class="secondary-nav-item-link" href="/tag/rock/artists">
#                             Artists
#
#                         </a></li><li class="navlist-item secondary-nav-item secondary-nav-item--albums"><a class="secondary-nav-item-link" href="/tag/rock/albums">
#                             Albums
#
#                         </a></li><li class="navlist-item secondary-nav-item secondary-nav-item--tracks"><a class="secondary-nav-item-link secondary-nav-item-link--active" href="/tag/rock/tracks">
#                             Tracks
#
#                                 <span class="sr-only">(current section)</span>
# </a></li><li class="navlist-item secondary-nav-item secondary-nav-item--wiki"><a class="secondary-nav-item-link" href="/tag/rock/wiki">
#                             Wiki
#
#                         </a></li><li class="navlist-item secondary-nav-item secondary-nav-item--shoutbox"><a class="secondary-nav-item-link" href="/tag/rock/shoutbox">
#                             Shouts
#
#                         </a></li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="adaptive-skin-container" id="mantle_skin">
# <div class="adaptive-skin-wrapper">
# <div class="adaptive-skin-left" id="adSkinLeft"></div>
# <div class="adaptive-skin-right" id="adSkinRight"></div>
# </div>
# <div class="content-top">
# <div class="content-top-inner-wrap">
# <div class="leader_plus_top lastfm-ad" data-ad="leader_plus_top" data-ads-placement='{"id": "leader_plus_top", "sizes": [[728, 90], [970, 66], [970, 250], [728, 91]], "targeting": {"pos": "top"}, "adblock_message": true}' id="leader_plus_top">
# </div>
# <div class="mobile_pos_1 lastfm-ad-mobile" data-ad="mobile_pos_1" data-ads-placement='{"id": "mobile_pos_1", "sizes": [[300, 250], [320, 50]], "is_mobile": true, "targeting": {"pos": "1"}, "adblock_message": true}' id="mobile_pos_1">
# </div>
# <p class="mpu-subscription-upsell mpu-subscription-upsell--mobile_pos_1">
#                 Don't want to see ads? <a data-analytics-action="SubscribeClick" data-analytics-label="AdUpsellCTA" href="/pro">Upgrade Now</a>
# </p>
# <div class="container content-top-lower">
# <h1 class="content-top-header">
#
#     Rock Tracks
#
#                         </h1>
# </div>
# </div>
# </div>
# <div class="container page-content">
# <div class="row">
# <div class="col-main">
# <section id="top-tracks-section">
# <table class="chartlist chartlist--with-index chartlist--with-index--length-3 chartlist--with-play chartlist--with-mobile-play chartlist--with-loved chartlist--with-artist chartlist--with-more chartlist--with-buylinks">
# <thead class="sr-only">
# <tr>
# <th>Rank</th>
# <th>Play</th>
# <th>Loved</th>
# <th>
#
#
#                         Track name
#
#                 </th>
# <th>Artist name </th>
# <th>Buy</th>
# <th>Options</th>
# </tr>
# </thead>
# <tbody data-playlisting-add-entries="">
# <tr class="chartlist-row chartlist-row--with-artist chartlist-row--with-buylinks js-focus-controls-container" data-ajax-form-state="" data-playlist-row="" data-scrobble-row="" itemprop="track" itemscope="" itemtype="http://schema.org/MusicRecording">
# <td class="chartlist-index">
#                
#             </td>
# <td class="chartlist-play">
# <a class="chartlist-play-button js-playlink" data-analytics-action="PlayTrackOnPage" data-analytics-label="youtube" data-artist-name="Gorillaz" data-artist-url="/music/Gorillaz" data-playlink-affiliate="youtube" data-track-name="Kids With Guns" data-track-url="/music/Gorillaz/_/Kids+With+Guns" data-youtube-id="VCkFSe3voRc" data-youtube-url="https://www.youtube.com/watch?v=VCkFSe3voRc" href="https://www.youtube.com/watch?v=VCkFSe3voRc" target="_blank" title="Play on YouTube">
#
#                     Play track
#
#             </a>
# </td>
# <td class="chartlist-loved">
# <div data-toggle-button="" data-toggle-button-current-state="unloved" data-toggle-button-group-id="87f4d5fa4e58481e30673299e0454873" data-toggle-button-states='[{"name": "unloved", "button_text": "Love this track", "url": null, "action": "love", "analytics_action": "LoveTrack", "event": "track.love"}, {"name": "loved", "button_text": "Unlove this track", "url": null, "action": "unlove", "analytics_action": "UnloveTrack", "event": "track.unlove"}]'>
# <a class="toggle-button chartlist-love-button" data-open-modal="/join/modal?action=love" href="/login?next=/tag/rock/tracks">
#                 Love this track
#             </a>
# </div>
# </td>
# <td class="chartlist-name" data-toggle-button="" data-toggle-button-current-state="unloved" data-toggle-button-group-id="87f4d5fa4e58481e30673299e0454873" itemprop="name">
# <a class="" href="/music/Gorillaz/_/Kids+With+Guns" title="Kids With Guns">Kids With Guns</a>
# </td>
# <td class="chartlist-artist" itemprop="byArtist" itemscope="" itemtype="http://schema.org/MusicGroup">
# <a href="/music/Gorillaz" title="Gorillaz">Gorillaz</a>
# </td>
# <td class="chartlist-buylinks focus-control">
# <div class="lazy-buylinks">
# <button aria-controls="buylinks-6a6b14f8-88ac-400b-8786-ede729651cc6" aria-expanded="false" class="disclose-trigger lazy-buylinks-toggle" data-disclose-lazy-buylinks="" data-dropdown-layout-at="center bottom+3" data-lazy-buylink-url="/music/Gorillaz/_/Kids+With+Guns/+partial/buylinks">Buy</button>
# <ul class="disclose-hide dropdown-menu-clickable buylinks-dropdown-menu" id="buylinks-6a6b14f8-88ac-400b-8786-ede729651cc6">
# <li aria-live="polite" class="menu-loading" data-lazy-buylinks-loading="">Loading</li>
# </ul>
# </div>
# </td>
# <td class="chartlist-more focus-control">
# <div>
# <button aria-controls="chartlist-more-388668e5-12d6-4a9e-9393-105f47341988" aria-expanded="false" class="disclose-trigger chartlist-more-button" data-disclose-lazy-buylinks="" data-dropdown-layout-at="center bottom+3" data-lazy-buylink-url="/music/Gorillaz/_/Kids+With+Guns/+partial/buylinks">More</button>
# <ul class="disclose-hide disclose-hide--js-only dropdown-menu-clickable chartlist-more-menu" id="chartlist-more-388668e5-12d6-4a9e-9393-105f47341988">
# <li class="visible-xs">
# <div data-toggle-button="" data-toggle-button-current-state="unloved" data-toggle-button-group-id="87f4d5fa4e58481e30673299e0454873" data-toggle-button-states='[{"name": "unloved", "button_text": "Love this track", "url": null, "action": "love", "analytics_action": "LoveTrack", "event": "track.love"}, {"name": "loved", "button_text": "Unlove this track", "url": null, "action": "unlove", "analytics_action": "UnloveTrack", "event": "track.unlove"}]'>
# <a class="toggle-button dropdown-menu-clickable-item chartlist-more-menu-love" data-open-modal="/join/modal?action=love" href="/login?next=/tag/rock/tracks">
#                 Love this track
#             </a>
# </div>
# </li>
# <li>
# <a class="mimic-link dropdown-menu-clickable-item more-item--obsession" data-open-modal="/join/modal?action=set-obsession&amp;back_to=%2Ftag%2Frock%2Ftracks" href="/login?next=/tag/rock/tracks">
#             Set track as current obsession
#         </a>
# </li>
# <li class="visible-xs">
# <span class="menu-title">
#
#                                     Get track
#
#                             </span>
# <ul class="buylinks-dropdown-menu">
# <li aria-live="polite" class="menu-loading" data-lazy-buylinks-loading="">Loading</li>
# </ul>
# </li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="chartlist-row chartlist-row--with-artist chartlist-row--with-buylinks js-focus-controls-container" data-ajax-form-state="" data-playlist-row="" data-scrobble-row="" itemprop="track" itemscope="" itemtype="http://schema.org/MusicRecording">
# <td class="chartlist-index">
#                 355
#             </td>
# <td class="chartlist-play">
# <a class="chartlist-play-button js-playlink" data-analytics-action="PlayTrackOnPage" data-analytics-label="youtube" data-artist-name="Billy Joel" data-artist-url="/music/Billy+Joel" data-playlink-affiliate="youtube" data-track-name="Piano Man" data-track-url="/music/Billy+Joel/_/Piano+Man" data-youtube-id="gxEPV4kolz0" data-youtube-url="https://www.youtube.com/watch?v=gxEPV4kolz0" href="https://www.youtube.com/watch?v=gxEPV4kolz0" target="_blank" title="Play on YouTube">
#
#                     Play track
#
#             </a>
# </td>
# <td class="chartlist-loved">
# <div data-toggle-button="" data-toggle-button-current-state="unloved" data-toggle-button-group-id="7e893d31fdf2684a6d54d1ec45227848" data-toggle-button-states='[{"name": "unloved", "button_text": "Love this track", "url": null, "action": "love", "analytics_action": "LoveTrack", "event": "track.love"}, {"name": "loved", "button_text": "Unlove this track", "url": null, "action": "unlove", "analytics_action": "UnloveTrack", "event": "track.unlove"}]'>
# <a class="toggle-button chartlist-love-button" data-open-modal="/join/modal?action=love" href="/login?next=/tag/rock/tracks">
#                 Love this track
#             </a>
# </div>
# </td>
# <td class="chartlist-name" data-toggle-button="" data-toggle-button-current-state="unloved" data-toggle-button-group-id="7e893d31fdf2684a6d54d1ec45227848" itemprop="name">
# <a class="" href="/music/Billy+Joel/_/Piano+Man" title="Piano Man">Piano Man</a>
# </td>
# <td class="chartlist-artist" itemprop="byArtist" itemscope="" itemtype="http://schema.org/MusicGroup">
# <a href="/music/Billy+Joel" title="Billy Joel">Billy Joel</a>
# </td>
# <td class="chartlist-buylinks focus-control">
# <div class="lazy-buylinks">
# <button aria-controls="buylinks-01c31349-1b25-4f87-955d-3c0829dc4bca" aria-expanded="false" class="disclose-trigger lazy-buylinks-toggle" data-disclose-lazy-buylinks="" data-dropdown-layout-at="center bottom+3" data-lazy-buylink-url="/music/Billy+Joel/_/Piano+Man/+partial/buylinks">Buy</button>
# <ul class="disclose-hide dropdown-menu-clickable buylinks-dropdown-menu" id="buylinks-01c31349-1b25-4f87-955d-3c0829dc4bca">
# <li aria-live="polite" class="menu-loading" data-lazy-buylinks-loading="">Loading</li>
# </ul>
# </div>
# </td>
# <td class="chartlist-more focus-control">
# <div>
# <button aria-controls="chartlist-more-4bebd240-31a6-4863-9a3c-a53b434070f2" aria-expanded="false" class="disclose-trigger chartlist-more-button" data-disclose-lazy-buylinks="" data-dropdown-layout-at="center bottom+3" data-lazy-buylink-url="/music/Billy+Joel/_/Piano+Man/+partial/buylinks">More</button>
# <ul class="disclose-hide disclose-hide--js-only dropdown-menu-clickable chartlist-more-menu" id="chartlist-more-4bebd240-31a6-4863-9a3c-a53b434070f2">
# <li class="visible-xs">
# <div data-toggle-button="" data-toggle-button-current-state="unloved" data-toggle-button-group-id="7e893d31fdf2684a6d54d1ec45227848" data-toggle-button-states='[{"name": "unloved", "button_text": "Love this track", "url": null, "action": "love", "analytics_action": "LoveTrack", "event": "track.love"}, {"name": "loved", "button_text": "Unlove this track", "url": null, "action": "unlove", "analytics_action": "UnloveTrack", "event": "track.unlove"}]'>
# <a class="toggle-button dropdown-menu-clickable-item chartlist-more-menu-love" data-open-modal="/join/modal?action=love" href="/login?next=/tag/rock/tracks">
#                 Love this track
#             </a>
# </div>
# </li>
# <li>
# <a class="mimic-link dropdown-menu-clickable-item more-item--obsession" data-open-modal="/join/modal?action=set-obsession&amp;back_to=%2Ftag%2Frock%2Ftracks" href="/login?next=/tag/rock/tracks">
#             Set track as current obsession
#         </a>
# </li>
# <li class="visible-xs">
# <span class="menu-title">
#
#                                     Get track
#
#                             </span>
# <ul class="buylinks-dropdown-menu">
# <li aria-live="polite" class="menu-loading" data-lazy-buylinks-loading="">Loading</li>
# </ul>
# </li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="chartlist-row chartlist-row--with-artist chartlist-row--with-buylinks js-focus-controls-container" data-ajax-form-state="" data-playlist-row="" data-scrobble-row="" itemprop="track" itemscope="" itemtype="http://schema.org/MusicRecording">
# <td class="chartlist-index">
#                 356
#             </td>
# <td class="chartlist-play">
# ...
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-bottom">
# <div class="container">
# <div class="row">
# <div class="col-xs-12 col-sm-10">
# <ul id="language-selector">
# <li class="footer-language footer-language--active">
# <strong>English</strong><span class="sr-only">current language</span>
# </li>
# <li class="footer-language">
# <form action="/i18n/setlang/" class="footer-language-form" method="post">
# <input name="language" type="hidden" value="de"/>
# <button class="mimic-link" name="de" type="submit">Deutsch</button>
# </form>
# </li>
# <li class="footer-language">
# <form action="/i18n/setlang/" class="footer-language-form" method="post">
# <input name="language" type="hidden" value="es"/>
# <button class="mimic-link" name="es" type="submit">Español</button>
# </form>
# </li>
# <li class="footer-language">
# <form action="/i18n/setlang/" class="footer-language-form" method="post">
# <input name="language" type="hidden" value="fr"/>
# <button class="mimic-link" name="fr" type="submit">Français</button>
# </form>
# </li>
# <li class="footer-language">
# <form action="/i18n/setlang/" class="footer-language-form" method="post">
# <input name="language" type="hidden" value="it"/>
# <button class="mimic-link" name="it" type="submit">Italiano</button>
# </form>
# </li>
# <li class="footer-language">
# <form action="/i18n/setlang/" class="footer-language-form" method="post">
# <input name="language" type="hidden" value="ja"/>
# <button class="mimic-link" name="ja" type="submit">日本語</button>
# </form>
# </li>
# <li class="footer-language">
# <form action="/i18n/setlang/" class="footer-language-form" method="post">
# <input name="language" type="hidden" value="pl"/>
# <button class="mimic-link" name="pl" type="submit">Polski</button>
# </form>
# </li>
# <li class="footer-language">
# <form action="/i18n/setlang/" class="footer-language-form" method="post">
# <input name="language" type="hidden" value="pt"/>
# <button class="mimic-link" name="pt" type="submit">Português</button>
# </form>
# </li>
# <li class="footer-language">
# <form action="/i18n/setlang/" class="footer-language-form" method="post">
# <input name="language" type="hidden" value="ru"/>
# <button class="mimic-link" name="ru" type="submit">Русский</button>
# </form>
# </li>
# <li class="footer-language">
# <form action="/i18n/setlang/" class="footer-language-form" method="post">
# <input name="language" type="hidden" value="sv"/>
# <button class="mimic-link" name="sv" type="submit">Svenska</button>
# </form>
# </li>
# <li class="footer-language">
# <form action="/i18n/setlang/" class="footer-language-form" method="post">
# <input name="language" type="hidden" value="tr"/>
# <button class="mimic-link" name="tr" type="submit">Türkçe</button>
# </form>
# </li>
# <li class="footer-language">
# <form action="/i18n/setlang/" class="footer-language-form" method="post">
# <input name="language" type="hidden" value="zh"/>
# <button class="mimic-link" name="zh" type="submit">简体中文</button>
# </form>
# </li>
# </ul>
# <p class="footer-timezone">
# <span data-lazy-load-content="/timezone" data-lazy-load-error-message="Timezone could not be loaded, try reloading the page." data-require="components/lazy-load-v3">
# </span>
# </p>
# <div class="footer-legal">
# <ul>
# <li class="footer-legal-item"><a href="http://www.cbsinteractive.com/" rel="nofollow">CBS Interactive</a> © 2024 <span itemprop="name">Last.fm</span> Ltd. All rights reserved</li>
# <li class="footer-legal-item"><a href="/legal/terms">Terms of Use</a></li>
# <li class="footer-legal-item"><a href="/legal/privacy">Privacy Policy</a></li>
# <li class="footer-legal-item"><a href="/legal">Legal Policies</a></li>
# <li class="footer-legal-item"><a class="ot-sdk-show-settings">Do Not Sell My Personal Information</a></li>
# <li class="footer-legal-item"><a href="https://careers.paramount.com/" target="_blank">Jobs at Paramount</a></li>
# <li class="footer-legal-item"><a href="http://www.last.fm" rel="nofollow">Last.fm Music</a></li>
# </ul>
# </div>
# </div>
# <div class="logo col-xs-12 col-sm-2">
# <p>Audioscrobbler</p>
# <img alt="Last.fm 'as' logo" height="20" loading="lazy" src="/static/images/footer_logo@2x.49ca51948b0a.png" width="37"/>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <section class="debug-log">
# <h2 class="debug-log-heading">API Calls</h2>
# </section>
# </div>
# <div data-ads-beacon="" data-ads-env="prod" data-ads-network="8264" data-ads-targeting='{"lang": "en", "beta": "yes", "ptype": "tag_tracks", "tag": "rock,alternative,alternativerock,hardrock,indie,classicrock,pop"}' data-ads-zone="/tag/tracks" id="data-ads"></div>
# </div>
# <div data-require="player/providers/spotify/spotify-provider" data-spotify-auth-modal="/player/modal/spotify" data-spotify-inactive-modal="/player/modal/spotify-inactive" data-spotify-initial-device-modal="/player/modal/spotify-initial-device-detection" data-spotify-premium-modal="/player/modal/spotify-premium"></div>
# <div aria-hidden="true" class="video-player video-player--v2 video-player--v2--no-controls" data-require="player/providers/youtube/youtube-provider-v2" id="youtube-video">
# <div class="video-player-inner-wrap">
# <div class="video-player-embed js-player"></div>
# <button class="video-player-close js-close-player">Close</button>
# </div>
# </div>
# <div class="sticky-playbar-container sticky-playbar-container--anon">
# <section aria-disabled="true" aria-label="audio player" class="player-bar-v2 inactive hidden-xs" data-player-error-cannot-play-item="Cannot play that item." data-player-error-track-unavailable="Track unavailable." data-player-modal-title="Play video" data-player-status-ad-playing="Ad playing" data-player-status-inactive=" " data-player-status-loading-spotify="Connecting Spotify…" data-player-status-spotify-auth-error="Could not authenticate with Spotify." data-require="player/controls-v2,player/status,player/tracking">
# <div class="close-player-bar-container">
# <button class="close-player-bar-button js-close js-close-player--v2">
#                 Close
#             </button>
# </div>
# <div class="video-player-background" data-animation-path="/static/animations/loading.d57fa5041751.json" data-require="components/loading-animation">
# <div class="video-player-loading-container"></div>
# </div>
# <div class="player-bar-controls-container">
# <div class="player-bar-container player-bar-container--no-artwork-1">
# <div class="player-bar-inner-wrap">
# <div class="player-bar-left-content">
# <div class="player-bar-now-playing">
# <div class="player-bar-now-playing-inner-wrap">
# <p aria-atomic="true" aria-label="now playing" aria-live="polite" class="player-bar-track js-player-status">
#                                     Loading player…
#                                 </p>
# <p class="player-bar-error js-player-error player-bar-status--hide">
# <span class="player-bar-error-message js-player-error-message"></span>
# </p>
# </div>
# </div>
# <div class="player-bar-controls">
# <button class="js-previous player-bar-btn player-bar-btn--previous" data-analytics-action="PlaybarBackTrack" disabled="">
#                                 Previous
#                             </button>
# <div class="player-bar-progress-wrap">
# <div aria-label="progress" class="player-bar-progress" role="timer">
# <div class="js-progress-slug player-bar-progress-slug">
# <span aria-label="remaining" class="sr-only js-progress-remaining player-bar-progress-remaining"></span>
# </div>
# </div>
# </div>
# <button class="js-next player-bar-btn player-bar-btn--next" data-analytics-action="PlaybarSkipTrack" disabled="">
#                                 Next
#                             </button>
# </div>
# </div>
# <div class="player-bar-right-content">
# <button class="js-play-pause player-bar-play-button-wrap" data-analytics-action="PlaybarResumeTrack" data-analytics-action-pause="PlaybarPauseTrack" data-string-pause="Pause" disabled="">
#                             Play
#                         </button>
# <div class="player-bar-context-buttons-wrap">
# <button class="js-next player-bar-btn player-bar-btn--next player-bar-now-playing-next-button" data-analytics-action="PlaybarSkipTrack" disabled="">
#                                 Next
#                             </button>
# <div class="player-bar-now-playing-meta-data-button">
# </div>
# <div class="player-bar-now-playing-settings-button">
# <button class="js-settings player-bar-settings-button">
#                                     Settings
#                                 </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="player-bar-settings-container">
# <ul class="player-bar-playback-options-spotify">
# <li class="player-bar-listening-on-container">
# <button class="js-switch-device player-bar-playback-options-switch-device">
# <span class="player-bar-listening-on js-player-bar-listening-on">
# </span>
# </button>
# </li>
# <li class="player-bar-settings-option player-bar-settings-option--spotify">
# <a class="js-source player-bar-playback-options-external-link" target="_blank">
#                             Open in Spotify Web Player
#                         </a>
# </li>
# <li class="player-bar-settings-option player-bar-settings-option--youtube">
# <a class="js-source player-bar-playback-options-external-link" target="_blank">
#                             Open on YouTube website
#                         </a>
# </li>
# <li class="player-bar-settings-option">
# <a class="player-bar-playback-options-settings player-bar-playback-options-change-source" href="/login?next=/settings/website">
#                             Change playback source
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# <div data-require="player/scrobble-client"></div>
# </section>
# <div class="masthead-popup masthead-popup--spotify-scrobbling masthead-popup--hidden" data-require="components/spotify-scrobbling-prompt,components/alert-dismissable,components/spotify-scrobbling-banner" data-spotify-scobbling-fail-modal="/socialmodal/spotify-scrobbling-fail" data-spotify-scobbling-success-modal="/socialmodal/spotify-scrobbling-success">
# <div class="masthead-popup-inner">
# <h3>Scrobble from Spotify?</h3>
# <p>Connect your Spotify account to your Last.fm account and scrobble everything you listen to, from any Spotify app on any device or platform.</p>
# <p>
# <a class="btn-primary js-setup-spotify-scrobbling" href="/settings/applications">
#                     Connect to Spotify
#                 </a>
# </p>
# <a class="masthead-popup-close js-alert-dismissable-close" data-close-ajax="" href="/nagbar/dismiss/cta/spotify-scrobbling-prompt?period=permanent">
#                 Dismiss
#             </a>
# </div>
# </div>
# </div>
# <div class="tonefuze tonefuze--mobile visible-xs" data-require="
#                 ads/tonefuze
#
#             " data-tonefuze-artist="BTS" data-tonefuze-flex="True" data-tonefuze-id="100006141" id="tonefuze-mobile">
# </div>
# <script class="js-modal-template" type="text/template">
#             <div class="modal-dialog" role="dialog" aria-labelledby="modal-label">
#                 <div class="modal-content" data-require="stats/base-v3">
#                     <div class="modal-actions">
#
#                         <div class="modal-buttons">
#                             <button class="modal-action-button modal-download js-download sr-only hidden"
#                                 data-analytics-social=""
#                                 target="_blank" href="#"
#                                 data-modal-action="download-image"
#                             >
#                                 Download
#                             </button>
#                             <button class="modal-action-button modal-dismiss js-close sr-only hidden">Close</button>
#                         </div>
#                     </div>
#                     <div js-modal-body class="modal-body">
#                     </div>
#                 </div>
#             </div>
#         </script>
# <script>
#             var immediateUseBidBarrelFunctions = ['auction', 'initialize', 'setTargeting', 'destroySlots', 'setConfig', 'on', 'setLazyLoad'];
#             (function(a){
#                 var w=window,b='BidBarrel',q='queue';w[b]=w[b]?w[b]:{};w[b][q]=w[b][q]?w[b][q]:[];
#                 a.forEach(function(z){w[b][z]=w[b][z]||function(){var c=arguments;w[b][q].push(function(r){w[b][z].apply(w[b],c);r()})}});
#             })(immediateUseBidBarrelFunctions);
#         </script><script async="" id="bb-lib" src="https://at.cbsi.com/lib/dist/prod/bidbarrel-lastfm.min.js"></script>
# <script class="js-adblock-message-template" type="text/template">
#
#
#     <div><div>
#         <section class="
#             adblock-message
#             adblock-message--adfree
#             link-block
#             js-link-block
#         ">
#             <p class="adblock-message-body">
#
#                     <strong>Browse ad-free</strong> with a premium Last.fm account
#
#             </p>
#
#             <a
#                 class="adblock-message-button link-block-target"
#                 href="/pro"
#                 data-analytics-action="SubscribeClick"
#                 data-analytics-label="AdblockMessageAdfree"
#             >Find out more</a>
#             <a
#                 href="/pro"
#                 class="
#                     js-link-block-cover-link
#                     link-block-cover-link
#                 "
#                 tabindex="-1"
#                 aria-hidden="true"
#                 data-analytics-action="SubscribeClick"
#                 data-analytics-label="AdblockMessageAdfree"
#             ></a>
#         </section>
#     </div></div>
#
#             </script>
# <script class="js-adblock-message-template" type="text/template">
#
#
#     <div><div>
#         <section class="
#             adblock-message
#             adblock-message--support
#             link-block
#             js-link-block
#         ">
#             <p class="adblock-message-body">
#
#                     <strong>Show your support</strong> with a premium Last.fm account
#
#             </p>
#
#             <a
#                 class="adblock-message-button link-block-target"
#                 href="/pro"
#                 data-analytics-action="SubscribeClick"
#                 data-analytics-label="AdblockMessageSupport"
#             >Find out more</a>
#             <a
#                 href="/pro"
#                 class="
#                     js-link-block-cover-link
#                     link-block-cover-link
#                 "
#                 tabindex="-1"
#                 aria-hidden="true"
#                 data-analytics-action="SubscribeClick"
#                 data-analytics-label="AdblockMessageSupport"
#             ></a>
#         </section>
#     </div></div>
#
#             </script>
# <script class="js-adblock-message-template" type="text/template">
#
#
#     <div><div>
#         <section class="
#             adblock-message
#             adblock-message--benefits
#             link-block
#             js-link-block
#         ">
#             <p class="adblock-message-body">
#
#                     <strong>Get exclusive benefits</strong> with a premium Last.fm account
#
#             </p>
#
#             <a
#                 class="adblock-message-button link-block-target"
#                 href="/pro"
#                 data-analytics-action="SubscribeClick"
#                 data-analytics-label="AdblockMessageBenefits"
#             >Find out more</a>
#             <a
#                 href="/pro"
#                 class="
#                     js-link-block-cover-link
#                     link-block-cover-link
#                 "
#                 tabindex="-1"
#                 aria-hidden="true"
#                 data-analytics-action="SubscribeClick"
#                 data-analytics-label="AdblockMessageBenefits"
#             ></a>
#         </section>
#     </div></div>
#
#             </script>
# <script>
#             window.lfmDomReadyCallback && window.lfmDomReadyCallback();
#             window.lfmDomReady = true;
#         </script>
# <link as="style" charset="utf-8" data-require="shim/rel-preload" href="/static/styles/build/app-8987b69d9c.de70972aa981.css" media="(min-width: 768px)" rel="preload"/>
# </body>
# </html>

# %%
soup.title.text
# Out:
# 'Top rock tracks | Last.fm'

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'EMPTY_ELEMENT_EVENT',
#  'END_ELEMENT_EVENT',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'START_ELEMENT_EVENT',
#  'STRING_ELEMENT_EVENT',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_clone',
#  '_decode_markup',
#  '_event_stream',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_format_tag',
#  '_indent_string',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_markup_is_url',
#  '_markup_resembles_filename',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'builder',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contains_replacement_characters',
#  'contents',
#  'css',
#  'currentTag',
#  'current_data',
#  'declared_html_encoding',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'default',
#  'descendants',
#  'element_classes',
#  'encode',
#  'encode_contents',
#  'endData',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'formatter_for_name',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'handle_data',
#  'handle_endtag',
#  'handle_starttag',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'interesting_string_types',
#  'isSelfClosing',
#  'is_empty_element',
#  'is_xml',
#  'known_xml',
#  'markup',
#  'name',
#  'namespace',
#  'new_string',
#  'new_tag',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'object_was_parsed',
#  'open_tag_counter',
#  'original_encoding',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parse_only',
#  'parserClass',
#  'parser_class',
#  'popTag',
#  'prefix',
#  'preserve_whitespace_tag_stack',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'pushTag',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'reset',
#  'select',
#  'select_one',
#  'self_and_descendants',
#  'setup',
#  'smooth',
#  'string',
#  'string_container',
#  'string_container_stack',
#  'strings',
#  'stripped_strings',
#  'tagStack',
#  'text',
#  'unwrap',
#  'wrap']

# %% [markdown]
# ### Canciones de rock

# %%
rock = []
tracks = soup.find_all('tr', class_='chartlist-row')
for track in tracks:
        # Extraer el nombre de la canción
        song = track.find('td', class_='chartlist-name').find('a').text.strip()
        
        # Extraer el nombre del artista
        artist = track.find('td', class_='chartlist-artist').find('a').text.strip()
        
        # Agregar la canción y el artista a la lista
        rock.append({'Canción': song, 'Artista': artist})

rock_df = pd.DataFrame(rock)
display(rock_df)
# Out:
#                                          Canción                   Artista
# 0                                          Naïve                 The Kooks
# 1                                Everybody Talks                Neon Trees
# 2                                      Faust Arp                 Radiohead
# 3                                 Kids With Guns                  Gorillaz
# 4                                      Piano Man                Billy Joel
# 5            Don't Stop Me Now - Remastered 2011                     Queen
# 6                                          LUNCH             Billie Eilish
# 7                                  Hold the Line                      Toto
# 8                                     On a Plain                   Nirvana
# 9                            The Final Countdown                    Europe
# 10                                         Black                 Pearl Jam
# 11                             Happier Than Ever             Billie Eilish
# 12             This Charming Man - 2011 Remaster                The Smiths
# 13                                          1979     The Smashing Pumpkins
# 14                                    Down Under               Men at Work
# 15                    Can't Help Falling in Love             Elvis Presley
# 16                         Climbing Up the Walls                 Radiohead
# 17                                   Close to Me                  The Cure
# 18                                Come On Eileen    Dexys Midnight Runners
# 19                                   In Too Deep                    Sum 41
# 20                                   Wicked Game               Chris Isaak
# 21                           For What It's Worth       Buffalo Springfield
# 22                                Sunday Morning                  Maroon 5
# 23          Here Comes the Sun - Remastered 2009               The Beatles
# 24                 Be Quiet and Drive (Far Away)                  Deftones
# 25                                    First Date                 blink-182
# 26                        Sympathy for the Devil        The Rolling Stones
# 27                                     Videotape                 Radiohead
# 28                                       Fat Lip                    Sum 41
# 29                                          Ride         twenty one pilots
# 30                                Gives You Hell  The All-American Rejects
# 31                     The Chain - 2004 Remaster             Fleetwood Mac
# 32  Another One Bites The Dust - Remastered 2011                     Queen
# 33                                           One                 Metallica
# 34                           Dirty Little Secret  The All-American Rejects
# 35                                          Iris             Goo Goo Dolls
# 36                              You're Beautiful               James Blunt
# 37                                   Tiny Dancer                Elton John
# 38                        The Adults Are Talking               The Strokes
# 39                                  Plug In Baby                      Muse
# 40                                Always Forever                     Cults
# 41                          Carry on Wayward Son                    Kansas
# 42                              We Will Rock You                     Queen
# 43                              Behind Blue Eyes               Limp Bizkit
# 44                                   Adam's Song                 blink-182
tracks?page=190"
h = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36 Edg/130.0.0.0"}
res = requests.get(url, headers=h)
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.text, "html.parser")
soup.title.text
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'EMPTY_ELEMENT_EVENT',
#  'END_ELEMENT_EVENT',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'START_ELEMENT_EVENT',
#  'STRING_ELEMENT_EVENT',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_clone',
#  '_decode_markup',
#  '_event_stream',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_format_tag',
#  '_indent_string',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_markup_is_url',
#  '_markup_resembles_filename',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'builder',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contains_replacement_characters',
#  'contents',
#  'css',
#  'currentTag',
#  'current_data',
#  'declared_html_encoding',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'default',
#  'descendants',
#  'element_classes',
#  'encode',
#  'encode_contents',
#  'endData',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'formatter_for_name',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'handle_data',
#  'handle_endtag',
#  'handle_starttag',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'interesting_string_types',
#  'isSelfClosing',
#  'is_empty_element',
#  'is_xml',
#  'known_xml',
#  'markup',
#  'name',
#  'namespace',
#  'new_string',
#  'new_tag',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'object_was_parsed',
#  'open_tag_counter',
#  'original_encoding',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parse_only',
#  'parserClass',
#  'parser_class',
#  'popTag',
#  'prefix',
#  'preserve_whitespace_tag_stack',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'pushTag',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'reset',
#  'select',
#  'select_one',
#  'self_and_descendants',
#  'setup',
#  'smooth',
#  'string',
#  'string_container',
#  'string_container_stack',
#  'strings',
#  'stripped_strings',
#  'tagStack',
#  'text',
#  'unwrap',
#  'wrap']

# %%
hip_hop = []
tracks = soup.find_all('tr', class_='chartlist-row')
for track in tracks:
        # Extraer el nombre de la canción
        song = track.find('td', class_='chartlist-name').find('a').text.strip()
        
        # Extraer el nombre del artista
        artist = track.find('td', class_='chartlist-artist').find('a').text.strip()
        
        # Agregar la canción y el artista a la lista
        hip_hop.append({'Canción': song, 'Artista': artist})

hip_hop_df = pd.DataFrame(hip_hop)
display(hip_hop_df)
# Out:
#                                               Canción                Artista
# 0                                            Ja to ja            Paktofonika
# 1                                       I Need a Girl               P. Diddy
# 2                        Zucker (feat. Vanessa Mason)              Peter Fox
# 3                         Werdz From The Ghetto Child             Gang Starr
# 4                                       Natural Green                  Blazo
# 5                                     It Was Whatever                Shlohmo
# 6                                             Mittrom             Mach-Hommy
# 7                                            Knockout             Yung Gravy
# 8                                           LA chA TA                   f(x)
# 9              Devil in a New Dress [Feat. Rick Ross]             Kanye West
# 10                                              Tyler                yxngxr1
# 11                             Galvanize (feat Q-Tip)  The Chemical Brothers
# 12                           Without You (feat. ROSE)               G-DRAGON
# 13                                          Interlude           Cypress Hill
# 14                             Cash and Carry Me Home              Ghostpoet
# 15                    6 Foot 7 Foot (feat. Cory Gunz)             Lil' Wayne
# 16                                             Stoner             Young Thug
# 17                                Fuck Everybody Else           Domo Genesis
# 18  If You Were to Get What You Deserve, You Would...            $uicideboy$
# 19                                    Falling in Love                   2NE1
# 20                                          Put It On             Mac Miller
# 21                                         Superstars       Styles of Beyond
# 22                                         Warm It Up                  Logic
# 23                                              Alone                   Lund
# 24                                            Bonjour                    Nas
# 25                Carry Out (feat. Justin Timberlake)              Timbaland
# 26                          Something For The Blunted           Cypress Hill
# 27                       Private (Remix) (Feat. Akon)             One Chance
# 28                                            flannel               Lil Peep
# 29                                       Police State              dead prez
# 30  What Does Your Soul Look Like (Part 1 - Blue S...              DJ Shadow
# 31                                        Game Theory              The Roots
# 32                   The Return (feat. Freddie Gibbs)            Danny Brown
# 33                                     Bück dich hoch              Deichkind
# 34                                        2 bit Blues              Kid Koala
# 35                                       Rock Da Spot                 Redman
# 36                                           Vampires             Atmosphere
# 37                                               3500           Travi$ Scott
# 38                                           Atrevido                Orishas
# 39                                         Governator              Green Day
# 40                                          Questions               Lootpack
# 41                                    Congratulations                  Drake
# 42                                       Plasticworld               Pendulum
# 43                                Hold Down the Block                    Nas
# 44                                        Wassup Bro!              CRAIG XEN
# 45                                    Linha de Frente                 Criolo
# 46                                        Reflections             Atmosphere
# 47                                      Keep The Beat        Eric B. & Rakim
# 48                                    Forget Me Thots             Yung Gravy
# 49                                        Vinca Rosea                MF DOOM

# %%
hip_hop_df['Género'] = 'Hip-Hop'
display(hip_hop_df)
# Out:
#                                               Canción                Artista  \
# 0                                            Ja to ja            Paktofonika
# 1                                       I Need a Girl               P. Diddy
# 2                        Zucker (feat. Vanessa Mason)              Peter Fox
# 3                         Werdz From The Ghetto Child             Gang Starr
# 4                                       Natural Green                  Blazo
# 5                                     It Was Whatever                Shlohmo
# 6                                             Mittrom             Mach-Hommy
# 7                                            Knockout             Yung Gravy
# 8                                           LA chA TA                   f(x)
# 9              Devil in a New Dress [Feat. Rick Ross]             Kanye West
# 10                                              Tyler                yxngxr1
# 11                             Galvanize (feat Q-Tip)  The Chemical Brothers
# 12                           Without You (feat. ROSE)               G-DRAGON
# 13                                          Interlude           Cypress Hill
# 14                             Cash and Carry Me Home              Ghostpoet
# 15                    6 Foot 7 Foot (feat. Cory Gunz)             Lil' Wayne
# 16                                             Stoner             Young Thug
# 17                                Fuck Everybody Else           Domo Genesis
# 18  If You Were to Get What You Deserve, You Would...            $uicideboy$
# 19                                    Falling in Love                   2NE1
# 20                                          Put It On             Mac Miller
# 21                                         Superstars       Styles of Beyond
# 22                                         Warm It Up                  Logic
# 23                                              Alone                   Lund
# 24                                            Bonjour                    Nas
# 25                Carry Out (feat. Justin Timberlake)              Timbaland
# 26                          Something For The Blunted           Cypress Hill
# 27                       Private (Remix) (Feat. Akon)             One Chance
# 28                                            flannel               Lil Peep
# 29                                       Police State              dead prez
# 30  What Does Your Soul Look Like (Part 1 - Blue S...              DJ Shadow
# 31                                        Game Theory              The Roots
# 32                   The Return (feat. Freddie Gibbs)            Danny Brown
# 33                                     Bück dich hoch              Deichkind
# 34                                        2 bit Blues              Kid Koala
# 35                                       Rock Da Spot                 Redman
# 36                                           Vampires             Atmosphere
# 37                                               3500           Travi$ Scott
# 38                                           Atrevido                Orishas
# 39                                         Governator              Green Day
# 40                                          Questions               Lootpack
# 41                                    Congratulations                  Drake
# 42                                       Plasticworld               Pendulum
# 43                                Hold Down the Block                    Nas
# 44                                        Wassup Bro!              CRAIG XEN
# 45                                    Linha de Frente                 Criolo
# 46                                        Reflections             Atmosphere
# 47                                      Keep The Beat        Eric B. & Rakim
# 48                                    Forget Me Thots             Yung Gravy
# 49                                        Vinca Rosea                MF DOOM
#
#      Género
# 0   Hip-Hop
# 1   Hip-Hop
# 2   Hip-Hop
# 3   Hip-Hop
# 4   Hip-Hop
# 5   Hip-Hop
# 6   Hip-Hop
# 7   Hip-Hop
# 8   Hip-Hop
# 9   Hip-Hop
# 10  Hip-Hop
# 11  Hip-Hop
# 12  Hip-Hop
# 13  Hip-Hop
# 14  Hip-Hop
# 15  Hip-Hop
# 16  Hip-Hop
# 17  Hip-Hop
# 18  Hip-Hop
# 19  Hip-Hop
# 20  Hip-Hop
# 21  Hip-Hop
# 22  Hip-Hop
# 23  Hip-Hop
# 24  Hip-Hop
# 25  Hip-Hop
# 26  Hip-Hop
# 27  Hip-Hop
# 28  Hip-Hop
# 29  Hip-Hop
# 30  Hip-Hop
# 31  Hip-Hop
# 32  Hip-Hop
# 33  Hip-Hop
# 34  Hip-Hop
# 35  Hip-Hop
# 36  Hip-Hop
# 37  Hip-Hop
# 38  Hip-Hop
# 39  Hip-Hop
# 40  Hip-Hop
# 41  Hip-Hop
# 42  Hip-Hop
# 43  Hip-Hop
# 44  Hip-Hop
# 45  Hip-Hop
# 46  Hip-Hop
# 47  Hip-Hop
# 48  Hip-Hop
# 49  Hip-Hop

# %% [markdown]
# ## Canciones Indie

# %%
url = "https://www.last.fm/tag/indie/tracks?page=190"
h = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36 Edg/130.0.0.0"}
res = requests.get(url, headers=h)
res.status_code
soup = BeautifulSoup(res.text, "html.parser")
soup.title.text
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'EMPTY_ELEMENT_EVENT',
#  'END_ELEMENT_EVENT',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'START_ELEMENT_EVENT',
#  'STRING_ELEMENT_EVENT',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_clone',
#  '_decode_markup',
#  '_event_stream',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_format_tag',
#  '_indent_string',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_markup_is_url',
#  '_markup_resembles_filename',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'builder',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contains_replacement_characters',
#  'contents',
#  'css',
#  'currentTag',
#  'current_data',
#  'declared_html_encoding',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'default',
#  'descendants',
#  'element_classes',
#  'encode',
#  'encode_contents',
#  'endData',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'formatter_for_name',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'handle_data',
#  'handle_endtag',
#  'handle_starttag',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'interesting_string_types',
#  'isSelfClosing',
#  'is_empty_element',
#  'is_xml',
#  'known_xml',
#  'markup',
#  'name',
#  'namespace',
#  'new_string',
#  'new_tag',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'object_was_parsed',
#  'open_tag_counter',
#  'original_encoding',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parse_only',
#  'parserClass',
#  'parser_class',
#  'popTag',
#  'prefix',
#  'preserve_whitespace_tag_stack',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'pushTag',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'reset',
#  'select',
#  'select_one',
#  'self_and_descendants',
#  'setup',
#  'smooth',
#  'string',
#  'string_container',
#  'string_container_stack',
#  'strings',
#  'stripped_strings',
#  'tagStack',
#  'text',
#  'unwrap',
#  'wrap']

# %%
indie = []
tracks = soup.find_all('tr', class_='chartlist-row')
for track in tracks:
        # Extraer el nombre de la canción
        song = track.find('td', class_='chartlist-name').find('a').text.strip()
        
        # Extraer el nombre del artista
        artist = track.find('td', class_='chartlist-artist').find('a').text.strip()
        
        # Agregar la canción y el artista a la lista
        indie.append({'Canción': song, 'Artista': artist})

indie_df = pd.DataFrame(indie)
display(indie_df)
# Out:
#                                Canción                    Artista
# 0                             Oh Mandy            The Spinto Band
# 1             Don't Go Back to Dalston                 Razorlight
# 2                The End of All Things        Panic! at the Disco
# 3                             Darkseid                     Grimes
# 4                             Personal                      Stars
# 5                          She's A Jar                      Wilco
# 6                            New Round                       Beck
# 7                             Headache                      Girls
# 8                                 3 AM                       HAIM
# 9                            Oh My God                  Ida Maria
# 10                        Made by Maid              Laura Marling
# 11                       Keep It Clean             Camera Obscura
# 12                         Forgiveness                   Yeasayer
# 13                           THE QUIET                Troye Sivan
# 14              On the Way to the Club                       Blur
# 15                     Baddie's Boogie               Babyshambles
# 16                     Titanium Expose                Sonic Youth
# 17                          Quesadilla              Walk the Moon
# 18                          Goin' Home               Dan Auerbach
# 19               Youth Against Fascism                Sonic Youth
# 20                      In the Morning             Built to Spill
# 21                            Sad Song           Au Revoir Simone
# 22  I Can See It (But I Can't Feel It)        my bloody valentine
# 23               Coat Check Dream Song                Bright Eyes
# 24                 Love Always Remains                       MGMT
# 25                      The Sky Lit Up                  PJ Harvey
# 26                    Wide Lovely Eyes  Nick Cave & the Bad Seeds
# 27                         Ten Minutes            The Get Up Kids
# 28                       Another World    Antony and the Johnsons
# 29                 The Christmas Waltz                  She & Him
# 30              What Would I Want? Sky          Animal Collective
# 31                      A Thing for Me                  Metronomy
# 32                    Strange Reunions                   Yeasayer
# 33            I've Wasted So Much Time                      Enjoy
# 34  The Other Side of Mt. Heart Attack                      Liars
# 35                      Second to Numb       Kings of Convenience
# 36       I Love You But I Love Me More                     Marina
# 37                  Within and Without                 Washed Out
# 38               The State of Dreaming      Marina & the Diamonds
# 39                        Strawberries                Asobi Seksu
# 40                           Blue Mind              Alexi Murdoch
# 41                     40 Mark Strasse                  The Shins
# 42      Strange News From Another Star                       Blur
# 43                 Slight Night Shiver                        M83
# 44                 Side with the Seeds                      Wilco
# 45                      Blue Christmas                Bright Eyes
# 46                   Something's Wrong   The Jesus and Mary Chain
# 47                       Can't Be Sure                The Sundays
# 48                         Out of Tune                Real Estate
# 49                          No Name #4              Elliott Smith

# %%
indie_df['Género'] = 'Indie'
display(indie_df)
# Out:
#                                Canción                    Artista Género
# 0                             Oh Mandy            The Spinto Band  Indie
# 1             Don't Go Back to Dalston                 Razorlight  Indie
# 2                The End of All Things        Panic! at the Disco  Indie
# 3                             Darkseid                     Grimes  Indie
# 4                             Personal                      Stars  Indie
# 5                          She's A Jar                      Wilco  Indie
# 6                            New Round                       Beck  Indie
# 7                             Headache                      Girls  Indie
# 8                                 3 AM                       HAIM  Indie
# 9                            Oh My God                  Ida Maria  Indie
# 10                        Made by Maid              Laura Marling  Indie
# 11                       Keep It Clean             Camera Obscura  Indie
# 12                         Forgiveness                   Yeasayer  Indie
# 13                           THE QUIET                Troye Sivan  Indie
# 18      Motion City Soundtrack  Dance
# 19                  Lily Allen  Dance
# 20                 The 2 Bears  Dance
# 21                   Faithless  Dance
# 22                 Major Lazer  Dance
# 23                  Alan Braxe  Dance
# 24                    Everglow  Dance
# 25                   Burl Ives  Dance
# 26              Верка Сердючка  Dance
# 27             Groove Coverage  Dance
# 28                  Dragonette  Dance
# 29                Alice Deejay  Dance
# 30                       3OH!3  Dance
# 31                     Tavares  Dance
# 32                   JEON SOMI  Dance
# 33                 Ace of Base  Dance
# 34                      Tiësto  Dance
# 35                     Perfume  Dance
# 36                 Against Me!  Dance
# 37                        GWSN  Dance
# 38                       Usher  Dance
# 39               Happy Mondays  Dance
# 40                I Blame Coco  Dance
# 41                   Glee Cast  Dance
# 42                David Guetta  Dance
# 43                  Mory Kanté  Dance
# 44                        Kygo  Dance
# 45               Chelsea Wolfe  Dance
# 46                   Timbaland  Dance
# 47                        Enur  Dance
# 48                    G-DRAGON  Dance
# 49                      Ca$his  Dance

# %% [markdown]
# ## Canciones Rnb

# %%
url = "https://www.last.fm/tag/rnb/tracks?page=190"
h = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36 Edg/130.0.0.0"}
res = requests.get(url, headers=h)
res.status_code
soup = BeautifulSoup(res.text, "html.parser")
soup.title.text
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'EMPTY_ELEMENT_EVENT',
#  'END_ELEMENT_EVENT',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'START_ELEMENT_EVENT',
#  'STRING_ELEMENT_EVENT',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_clone',
#  '_decode_markup',
#  '_event_stream',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_format_tag',
#  '_indent_string',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_markup_is_url',
#  '_markup_resembles_filename',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'builder',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contains_replacement_characters',
#  'contents',
#  'css',
#  'currentTag',
#  'current_data',
#  'declared_html_encoding',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'default',
#  'descendants',
#  'element_classes',
#  'encode',
#  'encode_contents',
#  'endData',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'formatter_for_name',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'handle_data',
#  'handle_endtag',
#  'handle_starttag',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'interesting_string_types',
#  'isSelfClosing',
#  'is_empty_element',
#  'is_xml',
#  'known_xml',
#  'markup',
#  'name',
#  'namespace',
#  'new_string',
#  'new_tag',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'object_was_parsed',
#  'open_tag_counter',
#  'original_encoding',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parse_only',
#  'parserClass',
#  'parser_class',
#  'popTag',
#  'prefix',
#  'preserve_whitespace_tag_stack',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'pushTag',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'reset',
#  'select',
#  'select_one',
#  'self_and_descendants',
#  'setup',
#  'smooth',
#  'string',
#  'string_container',
#  'string_container_stack',
#  'strings',
#  'stripped_strings',
#  'tagStack',
#  'text',
#  'unwrap',
#  'wrap']

# %%
rnb = []
tracks = soup.find_all('tr', class_='chartlist-row')
for track in tracks:
        # Extraer el nombre de la canción
        song = track.find('td', class_='chartlist-name').find('a').text.strip()
        
        # Extraer el nombre del artista
        artist = track.find('td', class_='chartlist-artist').find('a').text.strip()
        
        # Agregar la canción y el artista a la lista
        rnb.append({'Canción': song, 'Artista': artist})

rnb_df = pd.DataFrame(rnb)
display(rnb_df)
# Out:
#                                               Canción  \
# 0                   Girl Don't Take Your Love From Me
# 1                                               Drunk
# 2                        Have You Ever Loved Somebody
# 3                                            Airplane
# 4                                          Stuttering
# 5                              Live For (feat. Drake)
# 6                                           Party Boy
# 7                                            25 Miles
# 8                                         Secret Love
# 9                                              Rasool
# 10                                First World Problem
# 11                  The Arms Of The One Who Loves You
# 12                          He Doesn't Know I'm Alive
# 13                               Pray for Forgiveness
# 14                                        Memory Lane
# 15                                          Thank You
# 16                                    Wasting My Time
# 17                                    For Lovers Only
# 18                                        Fly Like Me
# 19                                          Affection
# 20                                           Keep You
# 21                  Bring It All to Me (feat. *NSync)
# 22                                 Keep Dancin' on Me
# 23                                          Electrify
# 24                                    You Ain't Right
# 25                                               Burn
# 26                          James Dean (I Wanna Know)
# 27                                              Again
# 28                                    Walking on Snow
# 29                                           2 Pieces
# 30         Empire State of Mind, Pt. II (Broken Down)
# 31                           Independent Women Part 1
# 32                                Suga Honey Iced Tea
# 33                                             Angels
# 34                                          Without U
# 35            Bateu (Participação Especial de Ruxell)
# 36                                    They Don't Know
# 37                                             Candid
# 38                                         Each Other
# 39                       I'm Qualified To Satisfy You
# 40                                       Now or Never
# 41                                      Call The Cops
# 42                                      Just A Moment
# 43                                   I Ain't Trippin'
# 44                                Dancing in the Dark
# 45                                       Femme Like U
# 46                                         By My Side
# 47                                 Take It Easy on Me
# 48                                   Used to Love Her
# 49  Until The End Of Time ft The Benjamin Wright O...
#
#                      Artista
# 0            Michael Jackson
# 1                      Tweet
# 2            Freddie Jackson
# 3              Magdalena Bay
# 4                Fefe Dobson
# 5                 The Weeknd
# 6                      Boris
# 7                Edwin Starr
# 8                Kelly Price
# 9                 Jill Scott
# 10  Unknown Mortal Orchestra
# 11                    Xscape
# 12             Janet Jackson
# 13               Alicia Keys
# 14           Minnie Riperton
# 15                   Estelle
# 16                   Boomkat
# 17                   Maxwell
# 18                    Chingy
# 19                Boys Noize
# 20                       JLS
# 21                    Blaque
# 22                     Ciara
# 23             Wynter Gordon
# 24             Janet Jackson
# 25            Jessica Mauboy
# 26        Daniel Bedingfield
# 27                   Kehlani
# 28             Jordin Sparks
# 29               Carl Thomas
# 30               Alicia Keys
# 31           Destiny's Child
# 32                     Kelis
# 33              Robin Thicke
# 34                       2PM
# 35                       IZA
# 36           Alexandra Burke
# 37                      Kllo
# 38          Katharine McPhee
# 39               Barry White
# 40                       Mýa
# 41                     Mario
# 42                       Nas
# 43                   Cherish
# 44              Faye Webster
# 45                    K-Maro
# 46                      Lund
# 47              Robin Thicke
# 48                  Jay Sean
# 49         Justin Timberlake

# %%
rnb_df['Género'] = 'Rnb'
display(rnb_df)
# Out:
#                                               Canción  \
# 0                   Girl Don't Take Your Love From Me
# 1                                               Drunk
# 2                        Have You Ever Loved Somebody
# 3                                            Airplane
# 4                                          Stuttering
# 5                              Live For (feat. Drake)
# 6                                           Party Boy
# 7                                            25 Miles
# 8                                         Secret Love
# 9                                              Rasool
# 10                                First World Problem
# 11                  The Arms Of The One Who Loves You
# 12                          He Doesn't Know I'm Alive
# 13                               Pray for Forgiveness
# 14                                        Memory Lane
# 15                                          Thank You
# 16                                    Wasting My Time
# 17                                    For Lovers Only
# 18                                        Fly Like Me
# 19                                          Affection
# 20                                           Keep You
# 21                  Bring It All to Me (feat. *NSync)
# 22                                 Keep Dancin' on Me
# 23                                          Electrify
# 24                                    You Ain't Right
# 25                                               Burn
# 26                          James Dean (I Wanna Know)
# 27                                              Again
# 28                                    Walking on Snow
# 29                                           2 Pieces
# 30         Empire State of Mind, Pt. II (Broken Down)
# 31                           Independent Women Part 1
# 32                                Suga Honey Iced Tea
# 33                                             Angels
# 34                                          Without U
# 35            Bateu (Participação Especial de Ruxell)
# 36                                    They Don't Know
# 37                                             Candid
# 38                                         Each Other
# 39                       I'm Qualified To Satisfy You
# 40                                       Now or Never
# 41                                      Call The Cops
# 42                                      Just A Moment
# 43                                   I Ain't Trippin'
# 44                                Dancing in the Dark
# 45                                       Femme Like U
# 46                                         By My Side
# 47                                 Take It Easy on Me
# 48                                   Used to Love Her
# 49  Until The End Of Time ft The Benjamin Wright O...
#
#                      Artista Género
# 0            Michael Jackson    Rnb
# 1                      Tweet    Rnb
# 2            Freddie Jackson    Rnb
# 3              Magdalena Bay    Rnb
# 4                Fefe Dobson    Rnb
# 5                 The Weeknd    Rnb
# 6                      Boris    Rnb
# 7                Edwin Starr    Rnb
# 8                Kelly Price    Rnb
# 9                 Jill Scott    Rnb
# 10  Unknown Mortal Orchestra    Rnb
# 11                    Xscape    Rnb
# 12             Janet Jackson    Rnb
# 13               Alicia Keys    Rnb
# 14           Minnie Riperton    Rnb
# 15                   Estelle    Rnb
# 16                   Boomkat    Rnb
# 17                   Maxwell    Rnb
# 18                    Chingy    Rnb
# 19                Boys Noize    Rnb
# 20                       JLS    Rnb
# 21                    Blaque    Rnb
# 22                     Ciara    Rnb
# 23             Wynter Gordon    Rnb
# 24             Janet Jackson    Rnb
# 25            Jessica Mauboy    Rnb
# 26        Daniel Bedingfield    Rnb
# 27                   Kehlani    Rnb
# 28             Jordin Sparks    Rnb
# 29               Carl Thomas    Rnb
# 30               Alicia Keys    Rnb
# 31           Destiny's Child    Rnb
# 32                     Kelis    Rnb
# 33              Robin Thicke    Rnb
# 34                       2PM    Rnb
# 35                       IZA    Rnb
# 36           Alexandra Burke    Rnb
# 37                      Kllo    Rnb
# 38          Katharine McPhee    Rnb
# 39               Barry White    Rnb
# 40                       Mýa    Rnb
# 41                     Mario    Rnb
# 42                       Nas    Rnb
# 43                   Cherish    Rnb
# 44              Faye Webster    Rnb
# 45                    K-Maro    Rnb
# 46                      Lund    Rnb
# 47              Robin Thicke    Rnb
# 48                  Jay Sean    Rnb
# 49         Justin Timberlake    Rnb

# %% [markdown]
# ## Canciones Rap

# %%
url = "https://www.last.fm/tag/rap/tracks?page=190"
h = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36 Edg/130.0.0.0"}
res = requests.get(url, headers=h)
res.status_code
soup = BeautifulSoup(res.text, "html.parser")
soup.title.text
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'EMPTY_ELEMENT_EVENT',
#  'END_ELEMENT_EVENT',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'START_ELEMENT_EVENT',
#  'STRING_ELEMENT_EVENT',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_clone',
#  '_decode_markup',
#  '_event_stream',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_format_tag',
#  '_indent_string',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_markup_is_url',
#  '_markup_resembles_filename',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'builder',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contains_replacement_characters',
#  'contents',
#  'css',
#  'currentTag',
#  'current_data',
#  'declared_html_encoding',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'default',
#  'descendants',
#  'element_classes',
#  'encode',
#  'encode_contents',
#  'endData',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'formatter_for_name',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'handle_data',
#  'handle_endtag',
#  'handle_starttag',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'interesting_string_types',
#  'isSelfClosing',
#  'is_empty_element',
#  'is_xml',
#  'known_xml',
#  'markup',
#  'name',
#  'namespace',
#  'new_string',
#  'new_tag',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'object_was_parsed',
#  'open_tag_counter',
#  'original_encoding',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parse_only',
#  'parserClass',
#  'parser_class',
#  'popTag',
#  'prefix',
#  'preserve_whitespace_tag_stack',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'pushTag',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'reset',
#  'select',
#  'select_one',
#  'self_and_descendants',
#  'setup',
#  'smooth',
#  'string',
#  'string_container',
#  'string_container_stack',
#  'strings',
#  'stripped_strings',
#  'tagStack',
#  'text',
#  'unwrap',
#  'wrap']

# %%
rap = []
tracks = soup.find_all('tr', class_='chartlist-row')
for track in tracks:
        # Extraer el nombre de la canción
        song = track.find('td', class_='chartlist-name').find('a').text.strip()
        
        # Extraer el nombre del artista
        artist = track.find('td', class_='chartlist-artist').find('a').text.strip()
        
        # Agregar la canción y el artista a la lista
        rap.append({'Canción': song, 'Artista': artist})

rap_df = pd.DataFrame(rap)
display(rap_df)
# Out:
#                                              Canción                 Artista
# 0                                               Gone                 TobyMac
# 1                                       Runaway Love                Ludacris
# 2                                               Hate                   JAY-Z
# 3                                                123              Smokepurpp
# 4                      Hold My Hand - Duet with Akon         Michael Jackson
# 5                                       Winter Blues                 JJ DOOM
# 6                                          Dear Sirs                    El-P
# 7                                        Not Tonight                Lil' Kim
# 8                        2 Vaults (feat. Lil Yachty)            Tee Grizzley
# 9                                            Wait Up                   Q-Tip
# 10                              Scientifical Madness         Jeru the Damaja
# 11                                      It Takes Two  Rob Base & DJ E-Z Rock
# 12                                            A game             Talib Kweli
# 13                                       Flyentology                    El-P
# 14                                      Still Livin'           Freddie Gibbs
# 15                                           Gunz Yo            Sage Francis
# 16                                             Tasty                 NCT 127
# 17                        Soldier (feat. Pivot Gang)                    Saba
# 18                                           Feel Me               Lil Wayne
# 19                               G Is for Girl (A-Z)                   Ciara
# 20                                          K.U.S.H.            Cypress Hill
# 21                                           Friends                 Whodini
# 22                                  Folk-Metaphysics                    Milo
# 23                                   Street Hop 2010           Royce da 5'9"
# 24                            Off That (feat. Drake)                   JAY-Z
# 25                                       Swoon Units         Digable Planets
# 26                                        Brainstorm              Gang Starr
# 27                    Nasty Girl (co-starring Plies)                Ludacris
# 28                                             Smile           Vince Staples
# 29                                       Mafia Music               Rick Ross
# 30                                   Big Momma Thang                Lil' Kim
# 31                                         All Spice                 MF DOOM
# 32                                       Round We Go           Dizzee Rascal
# 33  Miscommunication (feat. Keri Hilson & Sebastian)               Timbaland
# 34                            What They Hittin' Foe?                Ice Cube
# 35           Top Off (feat. JAY Z, Future & Beyoncé)               DJ Khaled
# 36                                          Campfire            Wu-Tang Clan
# 37                               The Rep Grows Bigga              Gang Starr
# 38                                          ON POINT                   Lucki
# 39                                praying to the sky                Lil Peep
# 40                                        Good Music               The Roots
# 41                                          Kamikaze             ScHoolboy Q
# 42                         Smack That (feat. Eminem)                    Akon
# 43                                        Ride Remix                Ace Hood
# 44                                         This City           Patrick Stump
# 45                                              NEON                DPR LIVE
# 46                                    Brussel Sprout              Young Nudy
# 47                         How It Was (Feat. Future)                 DJ Esco
# 48                                      Beyond Words              Wax Tailor
# 49                                          Hands Up                    T.I.

# %%
rap_df['Género'] = 'Rap'
display(rap_df)
# Out:
#                                              Canción                 Artista  \
# 0                                               Gone                 TobyMac
# 1                                       Runaway Love                Ludacris
# 2                                               Hate                   JAY-Z
# 3                                                123              Smokepurpp
# 4                      Hold My Hand - Duet with Akon         Michael Jackson
# 5                                       Winter Blues                 JJ DOOM
# 6                                          Dear Sirs                    El-P
# 7                                        Not Tonight                Lil' Kim
# 8                        2 Vaults (feat. Lil Yachty)            Tee Grizzley
# 9                                            Wait Up                   Q-Tip
# 10                              Scientifical Madness         Jeru the Damaja
# 11                                      It Takes Two  Rob Base & DJ E-Z Rock
# 12                                            A game             Talib Kweli
# 13                                       Flyentology                    El-P
# 14                                      Still Livin'           Freddie Gibbs
# 15                                           Gunz Yo            Sage Francis
# 16                                             Tasty                 NCT 127
# 17                        Soldier (feat. Pivot Gang)                    Saba
# 18                                           Feel Me               Lil Wayne
# 19                               G Is for Girl (A-Z)                   Ciara
# 20                                          K.U.S.H.            Cypress Hill
# 21                                           Friends                 Whodini
# 22                                  Folk-Metaphysics                    Milo
# 23                                   Street Hop 2010           Royce da 5'9"
# 24                            Off That (feat. Drake)                   JAY-Z
# 25                                       Swoon Units         Digable Planets
# 26                                        Brainstorm              Gang Starr
# 27                    Nasty Girl (co-starring Plies)                Ludacris
# 28                                             Smile           Vince Staples
# 29                                       Mafia Music               Rick Ross
# 30                                   Big Momma Thang                Lil' Kim
# 31                                         All Spice                 MF DOOM
# 32                                       Round We Go           Dizzee Rascal
# 33  Miscommunication (feat. Keri Hilson & Sebastian)               Timbaland
# 34                            What They Hittin' Foe?                Ice Cube
# 35           Top Off (feat. JAY Z, Future & Beyoncé)               DJ Khaled
# 36                                          Campfire            Wu-Tang Clan
# 37                               The Rep Grows Bigga              Gang Starr
# 38                                          ON POINT                   Lucki
# 39                                praying to the sky                Lil Peep
# 40                                        Good Music               The Roots
# 41                                          Kamikaze             ScHoolboy Q
# 42                         Smack That (feat. Eminem)                    Akon
# 43                                        Ride Remix                Ace Hood
# 44                                         This City           Patrick Stump
# 45                                              NEON                DPR LIVE
# 46                                    Brussel Sprout              Young Nudy
# 47                         How It Was (Feat. Future)                 DJ Esco
# 48                                      Beyond Words              Wax Tailor
# 49                                          Hands Up                    T.I.
#
#    Género
# 0     Rap
# 1     Rap
# 2     Rap
# 3     Rap
# 4     Rap
# 5     Rap
# 6     Rap
# 7     Rap
# 8     Rap
# 9     Rap
# 10    Rap
# 11    Rap
# 12    Rap
# 13    Rap
# 14    Rap
# 15    Rap
# 16    Rap
# 17    Rap
# 18    Rap
# 19    Rap
# 20    Rap
# 21    Rap
# 22    Rap
# 23    Rap
# 24    Rap
# 25    Rap
# 26    Rap
# 27    Rap
# 28    Rap
# 29    Rap
# 30    Rap
# 31    Rap
# 32    Rap
# 33    Rap
# 34    Rap
# 35    Rap
# 36    Rap
# 37    Rap
# 38    Rap
# 39    Rap
# 40    Rap
# 41    Rap
# 42    Rap
# 43    Rap
# 44    Rap
# 45    Rap
# 46    Rap
# 47    Rap
# 48    Rap
# 49    Rap

# %% [markdown]
# ## Canciones Alternativa

# %%
url = "https://www.last.fm/tag/alternative/tracks?page=190"
h = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36 Edg/130.0.0.0"}
res = requests.get(url, headers=h)
res.status_code
soup = BeautifulSoup(res.text, "html.parser")
soup.title.text
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'EMPTY_ELEMENT_EVENT',
#  'END_ELEMENT_EVENT',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'START_ELEMENT_EVENT',
#  'STRING_ELEMENT_EVENT',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_clone',
#  '_decode_markup',
#  '_event_stream',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_format_tag',
#  '_indent_string',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_markup_is_url',
#  '_markup_resembles_filename',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'builder',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contains_replacement_characters',
#  'contents',
#  'css',
#  'currentTag',
#  'current_data',
#  'declared_html_encoding',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'default',
#  'descendants',
#  'element_classes',
#  'encode',
#  'encode_contents',
#  'endData',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'formatter_for_name',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'handle_data',
#  'handle_endtag',
#  'handle_starttag',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'interesting_string_types',
#  'isSelfClosing',
#  'is_empty_element',
#  'is_xml',
#  'known_xml',
#  'markup',
#  'name',
#  'namespace',
#  'new_string',
#  'new_tag',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'object_was_parsed',
#  'open_tag_counter',
#  'original_encoding',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parse_only',
#  'parserClass',
#  'parser_class',
#  'popTag',
#  'prefix',
#  'preserve_whitespace_tag_stack',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'pushTag',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'reset',
#  'select',
#  'select_one',
#  'self_and_descendants',
#  'setup',
#  'smooth',
#  'string',
#  'string_container',
#  'string_container_stack',
#  'strings',
#  'stripped_strings',
#  'tagStack',
#  'text',
#  'unwrap',
#  'wrap']

# %%
alt = []
tracks = soup.find_all('tr', class_='chartlist-row')
for track in tracks:
        # Extraer el nombre de la canción
        song = track.find('td', class_='chartlist-name').find('a').text.strip()
        
        # Extraer el nombre del artista
        artist = track.find('td', class_='chartlist-artist').find('a').text.strip()
        
        # Agregar la canción y el artista a la lista
        alt.append({'Canción': song, 'Artista': artist})

alt_df = pd.DataFrame(alt)
display(alt_df)
# Out:
#                                   Canción                Artista
# 0                          Elevator Music                   Beck
# 1                           Morning Theft           Jeff Buckley
# 2                             Extra Kings         The Avalanches
# 3                        LIFE AFTER SALEM              Lil Nas X
# 4                          Elephant Stone        The Stone Roses
# 5                                  Pretty             The Weeknd
# 6                             Don't Leave              Snakehips
# 7                     Back Stabbin' Betty      Cage the Elephant
# 8                      We Danced Together              The Rakes
# 9         The Boy Who Destroyed the World                    AFI
# 10                   Happiness in Slavery        Nine Inch Nails
# 11                               Batphone         Arctic Monkeys
# 12                          Be Aggressive          Faith No More
# 13                      Evening / Morning    Bombay Bicycle Club
# 14                         Monday Morning                   Pulp
# 15    Wolves (Song of the Shepherd's Dog)            Iron & Wine
# 16                             Everything      Alanis Morissette
# 17                           Hanginaround         Counting Crows
# 18                              20 Dollar                 M.I.A.
# 19                               Sidewalk         Built to Spill
# 20                      This Charming Man    Death Cab for Cutie
# 21                 She'll Come Back To Me                   Cake
# 22                              Confusion        Alice in Chains
# 23                   Put Your Money on Me            Arcade Fire
# 24                       The Price We Pay      A Day to Remember
# 25                         Rainbowarriors              CocoRosie
# 26                              Copy of A        Nine Inch Nails
# 27                            Not a Crime         Gogol Bordello
# 28                           Exercise One           Joy Division
# 29                           Union Square              Tom Waits
# 30                                   Tear  The Smashing Pumpkins
# 31  Ibi Dreams of Pavement (A Better Day)    Broken Social Scene
# 32                             What I See             Black Flag
# 33                                 Amelia          Cocteau Twins
# 34                              Superstar            Beach House
# 35                      Tahquamenon Falls         Sufjan Stevens
# 36                           India Rubber              Radiohead
# 37                          Let Love Rule          Lenny Kravitz
# 38                               Got Some              Pearl Jam
# 39                            Art Is Hard                Cursive
# 40                              I'm Above             Mad Season
# 41               Letting the Cables Sleep                   Bush
# 42                         Wild Wild Life          Talking Heads
# 43                           Just Tonight        Jimmy Eat World
# 44  Anthems for a Seventeen Year Old Girl    Broken Social Scene
# 45                    Fiddle and the Drum       A Perfect Circle
# 46                     We Rule the School    Belle and Sebastian
# 47                          In This Diary             The Ataris
# 48                       Let's Have a War       A Perfect Circle
# 49                        Closet Romantic           Damon Albarn

# %%
alt_df['Género'] = 'Alternative'
display(alt_df)
# Out:
#                                   Canción                Artista       Género
# 0                          Elevator Music                   Beck  Alternative
# 1                           Morning Theft           Jeff Buckley  Alternative
# 2                             Extra Kings         The Avalanches  Alternative
# 3                        LIFE AFTER SALEM              Lil Nas X  Alternative
# 4                          Elephant Stone        The Stone Roses  Alternative
# 5                                  Pretty             The Weeknd  Alternative
# 6                             Don't Leave              Snakehips  Alternative
# 7                     Back Stabbin' Betty      Cage the Elephant  Alternative
# 8                      We Danced Together              The Rakes  Alternative
# 9         The Boy Who Destroyed the World                    AFI  Alternative
# 10                   Happiness in Slavery        Nine Inch Nails  Alternative
# 11                               Batphone         Arctic Monkeys  Alternative
# 12                          Be Aggressive          Faith No More  Alternative
# 13                      Evening / Morning    Bombay Bicycle Club  Alternative
# 14                         Monday Morning                   Pulp  Alternative
# 15    Wolves (Song of the Shepherd's Dog)            Iron & Wine  Alternative
# 16                             Everything      Alanis Morissette  Alternative
# 17                           Hanginaround         Counting Crows  Alternative
# 18                              20 Dollar                 M.I.A.  Alternative
# 19                               Sidewalk         Built to Spill  Alternative
# 20                      This Charming Man    Death Cab for Cutie  Alternative
# 21                 She'll Come Back To Me                   Cake  Alternative
# 22                              Confusion        Alice in Chains  Alternative
# 23                   Put Your Money on Me            Arcade Fire  Alternative
# 24                       The Price We Pay      A Day to Remember  Alternative
# 25                         Rainbowarriors              CocoRosie  Alternative
# 26                              Copy of A        Nine Inch Nails  Alternative
# 27                            Not a Crime         Gogol Bordello  Alternative
# 28                           Exercise One           Joy Division  Alternative
# 29                           Union Square              Tom Waits  Alternative
# 30                                   Tear  The Smashing Pumpkins  Alternative
# 31  Ibi Dreams of Pavement (A Better Day)    Broken Social Scene  Alternative
# 32                             What I See             Black Flag  Alternative
# 33                                 Amelia          Cocteau Twins  Alternative
# 34                              Superstar            Beach House  Alternative
# 35                      Tahquamenon Falls         Sufjan Stevens  Alternative
# 36                           India Rubber              Radiohead  Alternative
# 37                          Let Love Rule          Lenny Kravitz  Alternative
# 38                               Got Some              Pearl Jam  Alternative
# 39                            Art Is Hard                Cursive  Alternative
# 40                              I'm Above             Mad Season  Alternative
# 41               Letting the Cables Sleep                   Bush  Alternative
# 42                         Wild Wild Life          Talking Heads  Alternative
# 43                           Just Tonight        Jimmy Eat World  Alternative
# 44  Anthems for a Seventeen Year Old Girl    Broken Social Scene  Alternative
# 45                    Fiddle and the Drum       A Perfect Circle  Alternative
# 46                     We Rule the School    Belle and Sebastian  Alternative
# 47                          In This Diary             The Ataris  Alternative
# 48                       Let's Have a War       A Perfect Circle  Alternative
# 49                        Closet Romantic           Damon Albarn  Alternative

# %% [markdown]
# ## Canciones Electronica

# %%
url = "https://www.last.fm/tag/electronic/tracks?page=190"
h = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36 Edg/130.0.0.0"}
res = requests.get(url, headers=h)
res.status_code
soup = BeautifulSoup(res.text, "html.parser")
soup.title.text
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'EMPTY_ELEMENT_EVENT',
#  'END_ELEMENT_EVENT',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'START_ELEMENT_EVENT',
#  'STRING_ELEMENT_EVENT',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_clone',
#  '_decode_markup',
#  '_event_stream',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_format_tag',
#  '_indent_string',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_markup_is_url',
#  '_markup_resembles_filename',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'builder',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contains_replacement_characters',
#  'contents',
#  'css',
#  'currentTag',
#  'current_data',
#  'declared_html_encoding',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'default',
#  'descendants',
#  'element_classes',
#  'encode',
#  'encode_contents',
#  'endData',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'formatter_for_name',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'handle_data',
#  'handle_endtag',
#  'handle_starttag',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'interesting_string_types',
#  'isSelfClosing',
#  'is_empty_element',
#  'is_xml',
#  'known_xml',
#  'markup',
#  'name',
#  'namespace',
#  'new_string',
#  'new_tag',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'object_was_parsed',
#  'open_tag_counter',
#  'original_encoding',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parse_only',
#  'parserClass',
#  'parser_class',
#  'popTag',
#  'prefix',
#  'preserve_whitespace_tag_stack',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'pushTag',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'reset',
#  'select',
#  'select_one',
#  'self_and_descendants',
#  'setup',
#  'smooth',
#  'string',
#  'string_container',
#  'string_container_stack',
#  'strings',
#  'stripped_strings',
#  'tagStack',
#  'text',
#  'unwrap',
#  'wrap']

# %%
elc = []
tracks = soup.find_all('tr', class_='chartlist-row')
for track in tracks:
        # Extraer el nombre de la canción
        song = track.find('td', class_='chartlist-name').find('a').text.strip()
        
        # Extraer el nombre del artista
        artist = track.find('td', class_='chartlist-artist').find('a').text.strip()
        
        # Agregar la canción y el artista a la lista
        elc.append({'Canción': song, 'Artista': artist})

elc_df = pd.DataFrame(elc)
display(elc_df)
# Out:
#                                       Canción                        Artista
# 17                 Eventually We Find Our Way  Trent Reznor and Atticus Ross
# 18                                      Calor                           Arca
# 19                                 Starstruck                  Years & Years
# 20                              Diamond Heart                    Alan Walker
# 21                                      Merci                        Stromae
# 22                             Move Your Body                      Eiffel 65
# 23                               Nothing Left                           Kygo
# 24                                 Mirror Man               The Human League
# 25                     Rise Up (feat. Vamero)                          Vinai
# 26                        Harmony in Blue III                     Tim Hecker
# 27                 1 Night (feat. Charli XCX)                      Mura Masa
# 28  Play Hard (feat. Ne-Yo & Akon) [New Edit]                   David Guetta
# 29                               Kitchen Sink                     Amon Tobin
# 30                          Come On You Slags                     Aphex Twin
# 31                                   Stay Now                            Jem
# 32          Drowned World/Substitute for Love                        Madonna
# 33                          Famous Last Words                    James Blake
# 34                                  Automatic                            ZHU
# 35                        A Night to Remember            High School Musical
# 36              Replay - Dorian Electra Remix                      Lady Gaga
# 37                                       Nova                         Burial
# 38                    A Little Bit, Sometimes                            múm
# 39                                   Princess                       Datarock
# 40                      Opal - Four Tet Remix                          Bicep
# 41                                     Street                     Jamie Woon
# 42            Sleepless feat. Jezzabell Doran                          Flume
# 43                                    No Good                    The Prodigy
# 44                                 Time Spent                    Deaf Center
# 45                                    Monster                        Starset
# 46                                    Colours                 The Avalanches
# 47                                       ZVVL                       CHVRCHES
# 48                                     XOXOXO                Black Eyed Peas
# 49                                       Fade                    Alan Walker
#
#         Género
# 0   Electronic
# 1   Electronic
# 2   Electronic
# 3   Electronic
# 4   Electronic
# 5   Electronic
# 6   Electronic
# 7   Electronic
# 8   Electronic
# 9   Electronic
# 10  Electronic
# 11  Electronic
# 12  Electronic
# 13  Electronic
# 14  Electronic
# 15  Electronic
# 16  Electronic
# 17  Electronic
# 18  Electronic
# 19  Electronic
# 20  Electronic
# 21  Electronic
# 22  Electronic
# 23  Electronic
# 24  Electronic
# 25  Electronic
# 26  Electronic
# 27  Electronic
# 28  Electronic
# 29  Electronic
# 30  Electronic
# 31  Electronic
# 32  Electronic
# 33  Electronic
# 34  Electronic
# 35  Electronic
# 36  Electronic
# 37  Electronic
# 38  Electronic
# 39  Electronic
# 40  Electronic
# 41  Electronic
# 42  Electronic
# 43  Electronic
# 44  Electronic
# 45  Electronic
# 46  Electronic
# 47  Electronic
# 48  Electronic
# 49  Electronic

# %% [markdown]
# ## Juntamos los dataframes

# %%
dataframes = [rock_df,hip_hop_df,indie_df,reggae_df,dance_df,rnb_df,rap_df,alt_df,elc_df]
universal_df = pd.concat(dataframes, ignore_index=True)
display(universal_df)
# Out:
#              Canción          Artista      Género
# 0              Naïve        The Kooks        Rock
# 1    Everybody Talks       Neon Trees        Rock
# 2          Faust Arp        Radiohead        Rock
# 3     Kids With Guns         Gorillaz        Rock
# 4          Piano Man       Billy Joel        Rock
# ..               ...              ...         ...
# 445          Monster          Starset  Electronic
# 446          Colours   The Avalanches  Electronic
# 447             ZVVL         CHVRCHES  Electronic
# 448           XOXOXO  Black Eyed Peas  Electronic
# 449             Fade      Alan Walker  Electronic
#
# [450 rows x 3 columns]
